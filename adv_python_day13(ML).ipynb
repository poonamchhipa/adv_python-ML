# %%
#Machine learning models=>
#(1)supervised ML models->data with label(column name) provided
#(2)unsupervised ML models->only data provided

# %%
#(1)supervised ML includes:
# ->linear regression
# ->logistic regression
# ->decision tree
# ->Randomforest
# ->naive bayes
# ->SVM
# ->knn

#(2)unsupervised ML models includes:
# ->PCA
# ->Kmeans
# ->Apriori

# %%
#what does ML model??
#Data--->divide(input,target)--->
#train and test data --->
#Machine(x_train,y_train)
#Machine(x_test) ---> predict ---> y_pred
#y_test
#metrics_score(y_test,y_pred)

# %% [markdown]
# #(1)linear regression

# %%
#linear regression->it will work when we have target column as numerical

# %%
#input(x)  output(y)
#1+1        2
#2+3        5
#5+6        11

#model([1+1,2+3],[2,5]--->model(5+6) --->??? ---> 15 <----y_pred
#y_test=11
#metrics_score(y_test,y_pred)

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("insurance.csv")

# %%
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
df=pd.get_dummies(df,columns=['sex','smoker','region'])

# %%
df.head(3)
# Out:
#    age    bmi  children     charges  sex_female  sex_male  smoker_no  \
# 0   19  27.90         0  16884.9240        True     False      False
# 1   18  33.77         1   1725.5523       False      True       True
# 2   28  33.00         3   4449.4620       False      True       True
#
#    smoker_yes  region_northeast  region_northwest  region_southeast  \
# 0        True             False             False             False
# 1       False             False             False              True
# 2       False             False             False              True
#
#    region_southwest
# 0              True
# 1             False
# 2             False

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,
                                               random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7835929767120723

# %%
df=pd.read_csv("tip.csv")

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df=pd.get_dummies(df,columns=['sex','smoker','day','time'])

# %%
df.head(2)
# Out:
#    total_bill   tip  size  sex_Female  sex_Male  smoker_No  smoker_Yes  \
# 0       16.99  1.01     2        True     False       True       False
# 1       10.34  1.66     3       False      True       True       False
#
#    day_Fri  day_Sat  day_Sun  day_Thur  time_Dinner  time_Lunch
# 0    False    False     True     False         True       False
# 1    False    False     True     False         True       False

# %%
x=df.drop(columns=['total_bill'])
y=df['total_bill']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,
                                               random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6240808714290969
