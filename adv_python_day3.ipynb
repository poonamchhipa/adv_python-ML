# %%
#dataframes=>
dataframe is mutable

# %%
import numpy as np
import pandas as pd

# %%
#import csv file with the help of pandas
df=pd.read_csv("C:\\Users\\hp\\Desktop\\Newdata\\placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df=pd.read_csv("placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head() #filter top 5 data from dataframe
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.head(2)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0

# %%
df.head(7)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1
# 5  8.77          6.19       1
# 6  5.34          7.09       0

# %%
df.tail() #filter last 5 data from dataframe
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.tail(4)
# Out:
#     cgpa  resume_score  placed
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample() #used when  we want diffrent diffrent data index and give random rows
# Out:
#     cgpa  resume_score  placed
# 73  5.76          6.48       0

# %%
df.sample(4)
# Out:
#     cgpa  resume_score  placed
# 70  7.12          7.41       1
# 3   6.88          7.27       1
# 33  8.43          7.73       1
# 69  8.06          9.06       1

# %%
df.columns
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
df.describe() #staticslly view of dataframe means how much entries are in numerical columns
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info() #give overall info about dataframe and give datatype information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df['placed'][0]=0
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12840\1859624805.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['placed'][0]=0
# C:\Users\hp\AppData\Local\Temp\ipykernel_12840\1859624805.py:1: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       0
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
#loc VS iloc=>if we want data in particular range....then we find this data using loc and iloc

# %%
#loc=>
#syntax=loc[row_range,column_names]
df.loc[1:3,['cgpa','placed']]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
#iloc=>
#syntax=iloc[row_range,column_range]
top_left_corner_df=df.iloc[:4,:3]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       0
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[2:5,['cgpa','placed']]
# Out:
#    cgpa  placed
# 2  8.27       1
# 3  6.88       1
# 4  7.52       1
# 5  8.77       1

# %%
df.iloc[2:5,[0,1,2]]
# Out:
#    cgpa  resume_score  placed
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df['cgpa'][1:4]=555
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12840\1888158231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cgpa'][1:4]=555

# %%
df
# Out:
#       cgpa  resume_score  placed
# 0     8.14          6.52       0
# 1   555.00          5.17       0
# 2   555.00          8.86       1
# 3   555.00          7.27       1
# 4     7.52          7.30       1
# ..     ...           ...     ...
# 95    6.33          6.38       0
# 96    8.23          7.76       1
# 97    6.65          7.78       0
# 98    8.14          5.63       1
# 99    6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
s=df.axes #it shows each columns datatype
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
df.empty #if there are missing values in our data it return true and if there are not missing values it return false
# Out:
# False

# %%
df.isnull().sum() #it return counts of total missing values of each column
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df['cgpa'][1:4]=None
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12840\1801583541.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cgpa'][1:4]=None

# %%
df['placed'][8:10]=None
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12840\1700925920.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['placed'][8:10]=None
# ...

# %%
df.isnull().sum() #for check missing values
# Out:
# cgpa            3
# resume_score    0
# placed          2
# dtype: int64

# %%
#for dropping or delete this missing values
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
p=df.dtypes #returns datatypes of each column
p
# Out:
# cgpa            float64
# resume_score    float64
# placed          float64
# dtype: object

# %%
i=df.ndim #dimension of dataframe and number of axes(it is 2)
i
# Out:
# 2

# %%
t=df.shape #shape=n(rows),n(columns)
t
# Out:
# (100, 3)

# %%
d=df.size  #row count*column count=total_elements
d
# Out:
# 300

# %%
a=df.values  #get a numpy array for df and it removes all column names and return remaining all values
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df=df.copy() 
#it copies dataframe and if we do changes in copied data, it will not reflect original data

# %%
p=df.sort_values(by='resume_score') #we can arange a specific column in ascending order with the use of sort and then it will update all columns
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
#if we want to change our column's datatype we use astype method
df['cgpa']=df['cgpa'].astype(int)  #type conversion
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
#if we write captial C in cgpa,means Cgpa instead of cgpa...it will become new column,bcz its case sensitive
df['Cgpa']=df['cgpa'].astype(int)  #type conversion
df
# Out:
#     cgpa  resume_score  placed  Cgpa
# 0      8          6.52       1     8
# 1      6          5.17       0     6
# 2      8          8.86       1     8
# 3      6          7.27       1     6
# 4      7          7.30       1     7
# ..   ...           ...     ...   ...
# 95     6          6.38       0     6
# 96     8          7.76       1     8
# 97     6          7.78       0     6
# 98     8          5.63       1     8
# 99     6          6.61       0     6
#
# [100 rows x 4 columns]

# %%
#now,if we want to delete this new column
df=df.drop(columns=['Cgpa'],axis=1) #here,axis=1 means columnwise operation
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
#we can delete multiple columns also
df2=df.copy()
df2
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df2=df2.drop(columns=['cgpa','placed'])

# %%
df2
# Out:
#     resume_score
# 0           6.52
# 1           5.17
# 2           8.86
# 3           7.27
# 4           7.30
# ..           ...
# 95          6.38
# 96          7.76
# 97          7.78
# 98          5.63
# 99          6.61
#
# [100 rows x 1 columns]

# %%
#dataframe is mutable thats why we can add,delete or drop any element in it
#add=>
t=df.add(4)
t
df['cgpa']=df['cgpa'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     20          6.52       1
# 1     18          5.17       0
# 2     20          8.86       1
# 3     18          7.27       1
# 4     19          7.30       1
# ..   ...           ...     ...
# 95    18          6.38       0
# 96    20          7.76       1
# 97    18          7.78       0
# 98    20          5.63       1
# 99    18          6.61       0
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     20          6.52       1
# 1     18          5.17       0
# 2     20          8.86       1
# 3     18          7.27       1
# 4     19          7.30       1
# ..   ...           ...     ...
# 95    18          6.38       0
# 96    20          7.76       1
# 97    18          7.78       0
# 98    20          5.63       1
# 99    18          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     28          6.52       1
# 1     26          5.17       0
# 2     28          8.86       1
# 3     26          7.27       1
# 4     27          7.30       1
# ..   ...           ...     ...
# 95    26          6.38       0
# 96    28          7.76       1
# 97    26          7.78       0
# 98    28          5.63       1
# 99    26          6.61       0
#
# [100 rows x 3 columns]

# %%
s=df.count()  #return frequency of each column
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p=df.max()  #give maximum element from each column
p
# Out:
# cgpa            29.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
q=df.min()  #give minimum element from each column
q
# Out:
# cgpa            25.00
# resume_score     4.95
# placed           0.00
# dtype: float64

# %%
r=df['cgpa'].mean()  #for find average
r
# Out:
# 26.47

# %%
s=df['cgpa'].median()
s
# Out:
# 26.0

# %%
s=df.sum()  #give sum of all elements of each column
s
# Out:
# cgpa            2647.00
# resume_score     693.05
# placed            50.00
# dtype: float64

# %%
#for filtering 
g=df.filter(items=['cgpa','placed'])
g
df[['cgpa','placed']]  #second option of filtering
# Out:
#     cgpa  placed
# 0     28       1
# 1     26       0
# 2     28       1
# 3     26       1
# 4     27       1
# ..   ...     ...
# 95    26       0
# 96    28       1
# 97    26       0
# 98    28       1
# 99    26       0
#
# [100 rows x 2 columns]

# %%
#if we want to filter our data rowwise=>
s=df.filter(items=[5,6],axis=0) #axis=0 means rowwise operation
s
# Out:
#    cgpa  resume_score  placed
# 5    28          6.19       1
# 6    25          7.09       0

# %%
t=df.filter(like='5',axis=0)
t
# Out:
#     cgpa  resume_score  placed
# 5     28          6.19       1
# 15    28          5.93       1
# 25    27          5.68       1
# 35    28          7.48       1
# 45    28          5.44       1
# 50    28          6.74       1
# 51    26          7.39       0
# 52    25          7.50       0
# 53    26          7.16       0
# 54    25          7.18       0
# 55    26          6.87       1
# 56    26          6.43       0
# 57    26          7.21       0
# 58    26          7.37       0
# 59    25          7.57       0
# 65    26          8.75       0
# 75    26          7.94       1
# 85    26          5.46       0
# 95    26          6.38       0

# %%
#for save the data we use to

# %%
s=df.to_dict()#save in dict
s
# Out:
# {'cgpa': {0: 28,
#   1: 26,
#   2: 28,
#   3: 26,
#   4: 27,
#   5: 28,
#   6: 25,
#   7: 26,
#   8: 26,
#   9: 27,
#   10: 26,
#   11: 25,
#   12: 26,
#   13: 28,
#   14: 27,
#   15: 28,
#   16: 28,
#   17: 27,
#   18: 25,
#   19: 26,
#   20: 25,
#   21: 26,
#   22: 26,
#   23: 26,
#   24: 28,
#   25: 27,
#   26: 26,
#   27: 25,
#   28: 27,
#   29: 26,
#   30: 27,
#   31: 25,
#   32: 25,
#   33: 28,
#   34: 28,
#   35: 28,
#   36: 28,
#   37: 29,
#   38: 26,
#   39: 27,
#   40: 28,
#   41: 28,
#   42: 26,
#   43: 28,
#   44: 25,
#   45: 28,
#   46: 25,
#   47: 27,
#   48: 25,
#   49: 25,
#   50: 28,
#   51: 26,
#   52: 25,
#   53: 26,
#   54: 25,
#   55: 26,
#   56: 26,
#   57: 26,
#   58: 26,
#   59: 25,
#   60: 25,
#   61: 26,
#   62: 25,
#   63: 28,
#   64: 27,
#   65: 26,
#   66: 28,
#   67: 26,
#   68: 26,
#   69: 28,
#   70: 27,
#   71: 27,
#   72: 27,
#   73: 25,
#   74: 25,
#   75: 26,
#   76: 29,
#   77: 25,
#   78: 25,
#   79: 25,
#   80: 27,
#   81: 26,
#   82: 27,
# ...

# %%
q=df.to_string() #save in string
q
# Out:
# '    cgpa  resume_score  placed\n0     28          6.52       1\n1     26          5.17       0\n2     28          8.86       1\n3     26          7.27       1\n4     27          7.30       1\n5     28          6.19       1\n6     25          7.09       0\n7     26          6.29       0\n8     26          6.71       0\n9     27          7.12       1\n10    26          6.35       0\n11    25          6.54       0\n12    26          7.01       0\n13    28          5.09       1\n14    27          6.25       1\n15    28          5.93       1\n16    28          7.64       1\n17    27          8.71       1\n18    25          5.88       0\n19    26          8.11       1\n20    25          8.06       0\n21    26          7.64       0\n22    26          5.77       0\n23    26          7.13       0\n24    28          6.18       1\n25    27          5.68       1\n26    26          6.47       0\n27    25          6.15       0\n28    27          7.67       1\n29    26          7.30       0\n30   
# ...

# %%
e=df.to_csv("path_location")
e

# %%
i=df.columns
i
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label=df.columns[0] #give first column label
label
# Out:
# 'cgpa'

# %%
p=df.columns.tolist() #list of column labels
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
q=df.columns.values  #array of column labels
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
#how to rename a column
p=df.rename(columns={'cgpa':'updated_cgpa','resume_score':'semester_marks'})
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             28            6.52       1
# 1             26            5.17       0
# 2             28            8.86       1
# 3             26            7.27       1
# 4             27            7.30       1
# ..           ...             ...     ...
# 95            26            6.38       0
# 96            28            7.76       1
# 97            26            7.78       0
# 98            28            5.63       1
# 99            26            6.61       0
#
# [100 rows x 3 columns]

# %%
df['updated_resume']=df['resume_score'].where(df['resume_score']>7,other='NO')
df
# Out:
#     cgpa  resume_score  placed updated_resume
# 0     28          6.52       1             NO
# 1     26          5.17       0             NO
# 2     28          8.86       1           8.86
# 3     26          7.27       1           7.27
# 4     27          7.30       1            7.3
# ..   ...           ...     ...            ...
# 95    26          6.38       0             NO
# 96    28          7.76       1           7.76
# 97    26          7.78       0           7.78
# 98    28          5.63       1             NO
# 99    26          6.61       0             NO
#
# [100 rows x 4 columns]

# %%
#Q.=>create an employee dataframe in which you have (emp_id,emp_name,department,salary)column
#and you have total 8 rows in your dataframe and you have to calculate:
#(1)top 3 data
#(2)bottom 4 data
#(3)create a new column in which whose salary is greater than 2000 only shows rest all are 0
#(4)check statically view and info() of dataframe?
