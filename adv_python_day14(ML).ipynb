# %% [markdown]
# #LogisticRegression Model=>

# %%
#LogisticRegression Model=>Supervised ML Model--->
#in this,we classify things when we have target column as categorical data

#Sigmoid Activation function->it is a backend function and we use it when 
#we have target column as categorical data and we have only 2 sub-categories

#sub-categories-->probabily 0-1-->
# if x>=0.5:
#     return 1
# else:
#     return 0

#Performance Evaluation Metrics--->Accuracy_score,precision,recall

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Social_Network_Ads.csv")

# %%
df.head(2)
# Out:
#     User ID Gender  Age  EstimatedSalary  Purchased
# 0  15624510   Male   19            19000          0
# 1  15810944   Male   35            20000          0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['Gender']=lb.fit_transform(df['Gender'])

# %%
df.head(2)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       1   19            19000          0
# 1  15810944       1   35            20000          0

# %%
df=df.drop(columns=['User ID'])

# %%
df.head(2)
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0       1   19            19000          0
# 1       1   35            20000          0

# %%
x=df.drop(columns=['Purchased'])
y=df['Purchased']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,
                                               random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8875

# %%
from sklearn.metrics import precision_score

# %%
precision_score(y_test,y_pred)  #True positive rate
# Out:
# 0.9130434782608695

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[50,  2],
#        [ 7, 21]], dtype=int64)

# %%
# 50--->tp
# 21-->tn
# 2-->fp
# 7-->fn

# %%
df=pd.read_csv("covid_toy.csv")

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer()

# %%
df['fever']=si.fit_transform(df[['fever']])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['gender']=lb.fit_transform(df['gender'])
df['cough']=lb.fit_transform(df['cough'])
df['city']=lb.fit_transform(df['city'])
df['has_covid']=lb.fit_transform(df['has_covid'])

# %%
df.head(2)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=['has_covid'])
y=df['has_covid']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,
                                               random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.75

# %%
from sklearn.metrics import precision_score

# %%
precision_score(y_test,y_pred)
# Out:
# 0.6

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[9, 4],
#        [1, 6]], dtype=int64)

# %%
# 9--->tp
# 6--->tn
# 4--->fp
# 1--->fn
