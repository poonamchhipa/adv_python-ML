# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("market_basket.csv" , header = None)

# %%
df.head(2)
# Out:
#         0          1        2               3             4   \
# 0   shrimp    almonds  avocado  vegetables mix  green grapes
# 1  burgers  meatballs     eggs             NaN           NaN
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN

# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in c:\users\hp\anaconda3\lib\site-packages (1.1.2)

# %%
# Data Processing 
transactions = [] 
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range(0,20)])

#Training the dataset 
from apyori import apriori 
rules = apriori(transactions , 
              min_support = 0.003 ,     #(3items * 7 days in week)/(Total Rows in dataset 7501)
              min_confidence = 0.2 ,
              min_lift = 3 , 
              min_length = 2) 

#Visualizing the results 
a = list(rules) 
result = [list(a[i][0]) for i in range(0 , len(a))]

# %%
df.shape
# Out:
# (7501, 20)

# %%
result
# Out:
# [['chicken', 'light cream'],
#  ['mushroom cream sauce', 'escalope'],
#  ['pasta', 'escalope'],
#  ['honey', 'fromage blanc'],
#  ['herb & pepper', 'ground beef'],
#  ['tomato sauce', 'ground beef'],
#  ['olive oil', 'light cream'],
#  ['whole wheat pasta', 'olive oil'],
#  ['shrimp', 'pasta'],
#  ['spaghetti', 'milk', 'avocado'],
#  ['burgers', 'milk', 'cake'],
#  ['chocolate', 'burgers', 'turkey'],
#  ['turkey', 'burgers', 'milk'],
#  ['frozen vegetables', 'tomatoes', 'cake'],
#  ['cereals', 'spaghetti', 'ground beef'],
#  ['chicken', 'milk', 'ground beef'],
#  ['chicken', 'light cream', 'nan'],
#  ['chicken', 'milk', 'olive oil'],
#  ['chicken', 'spaghetti', 'olive oil'],
#  ['chocolate', 'frozen vegetables', 'shrimp'],
#  ['chocolate', 'herb & pepper', 'ground beef'],
#  ['chocolate', 'milk', 'soup'],
#  ['spaghetti', 'cooking oil', 'ground beef'],
#  ['eggs', 'herb & pepper', 'ground beef'],
#  ['spaghetti', 'eggs', 'red wine'],
#  ['nan', 'mushroom cream sauce', 'escalope'],
#  ['pasta', 'nan', 'escalope'],
#  ['french fries', 'herb & pepper', 'ground beef'],
#  ['honey', 'fromage blanc', 'nan'],
#  ['frozen vegetables', 'tomatoes', 'green tea'],
#  ['frozen vegetables', 'spaghetti', 'ground beef'],
#  ['frozen vegetables', 'milk', 'olive oil'],
#  ['frozen vegetables', 'milk', 'soup'],
#  ['frozen vegetables', 'milk', 'tomatoes'],
#  ['frozen vegetables', 'shrimp', 'mineral water'],
#  ['frozen vegetables', 'spaghetti', 'olive oil'],
#  ['frozen vegetables', 'spaghetti', 'shrimp'],
#  ['frozen vegetables', 'tomatoes', 'shrimp'],
#  ['frozen vegetables', 'spaghetti', 'tomatoes'],
#  ['spaghetti', 'ground beef', 'grated cheese'],
#  ['tomatoes', 'green tea', 'ground beef'],
#  ['milk', 'herb & pepper', 'ground beef'],
#  ['mineral water', 'herb & pepper', 'ground beef'],
#  ['nan', 'herb & pepper', 'ground beef'],
#  ['spaghetti', 'herb & pepper', 'ground beef'],
#  ['milk', 'olive oil', 'ground beef'],
#  ['milk', 'soup', 'ground beef'],
#  ['nan', 'tomato sauce', 'ground beef'],
#  ['spaghetti', 'pepper', 'ground beef'],
#  ['spaghetti', 'shrimp', 'ground beef'],
#  ['spaghetti', 'tomato sauce', 'ground beef'],
#  ['spaghetti', 'mineral water', 'light cream'],
#  ['olive oil', 'light cream', 'nan'],
#  ['milk', 'olive oil', 'shrimp'],
#  ['milk', 'olive oil', 'soup'],
#  ['spaghetti', 'milk', 'olive oil'],
#  ['milk', 'tomatoes', 'soup'],
#  ['spaghetti', 'milk', 'whole wheat pasta'],
#  ['olive oil', 'mineral water', 'soup'],
#  ['whole wheat pasta', 'olive oil', 'mineral water'],
#  ['whole wheat pasta', 'olive oil', 'nan'],
#  ['pasta', 'shrimp', 'nan'],
#  ['spaghetti', 'pancakes', 'olive oil'],
#  ['spaghetti', 'olive oil', 'tomatoes'],
#  ['spaghetti', 'whole wheat rice', 'tomatoes'],
#  ['spaghetti', 'milk', 'avocado', 'nan'],
#  ['burgers', 'milk', 'cake', 'nan'],
#  ['chocolate', 'burgers', 'turkey', 'nan'],
#  ['turkey', 'burgers', 'milk', 'nan'],
#  ['frozen vegetables', 'tomatoes', 'cake', 'nan'],
#  ['cereals', 'spaghetti', 'nan', 'ground beef'],
#  ['chicken', 'milk', 'nan', 'ground beef'],
#  ['chicken', 'milk', 'olive oil', 'nan'],
#  ['chicken', 'spaghetti', 'olive oil', 'nan'],
#  ['chocolate', 'eggs', 'mineral water', 'ground beef'],
#  ['chocolate', 'frozen vegetables', 'mineral water', 'ground beef'],
#  ['chocolate', 'spaghetti', 'frozen vegetables', 'ground beef'],
#  ['chocolate', 'frozen vegetables', 'mineral water', 'milk'],
#  ['chocolate', 'spaghetti', 'frozen vegetables', 'milk'],
#  ['chocolate', 'shrimp', 'frozen vegetables', 'mineral water'],
#  ['chocolate', 'frozen vegetables', 'shrimp', 'nan'],
#  ['chocolate', 'nan', 'herb & pepper', 'ground beef'],
#  ['chocolate', 'milk', 'soup', 'nan'],
#  ['chocolate', 'spaghetti', 'olive oil', 'mineral water'],
#  ['chocolate', 'shrimp', 'spaghetti', 'mineral water'],
#  ['spaghetti', 'nan', 'cooking oil', 'ground beef'],
#  ['frozen vegetables', 'milk', 'eggs', 'mineral water'],
#  ['eggs', 'nan', 'herb & pepper', 'ground beef'],
#  ['spaghetti', 'eggs', 'red wine', 'nan'],
#  ['french fries', 'nan', 'herb & pepper', 'ground beef'],
#  ['spaghetti', 'milk', 'mineral water', 'frozen smoothie'],
#  ['frozen vegetables', 'tomatoes', 'green tea', 'nan'],
#  ['frozen vegetables', 'milk', 'mineral water', 'ground beef'],
#  ['frozen vegetables', 'spaghetti', 'milk', 'ground beef'],
#  ['frozen vegetables', 'spaghetti', 'mineral water', 'ground beef'],
#  ['frozen vegetables', 'spaghetti', 'nan', 'ground beef'],
#  ['frozen vegetables', 'milk', 'olive oil', 'mineral water'],
#  ['frozen vegetables', 'milk', 'mineral water', 'soup'],
#  ['frozen vegetables', 'spaghetti', 'milk', 'mineral water'],
#  ['frozen vegetables', 'milk', 'olive oil', 'nan'],
#  ['frozen vegetables', 'milk', 'soup', 'nan'],
#  ['frozen vegetables', 'milk', 'tomatoes', 'nan'],
#  ['frozen vegetables', 'shrimp', 'mineral water', 'nan'],
#  ['frozen vegetables', 'shrimp', 'spaghetti', 'mineral water'],
#  ['frozen vegetables', 'spaghetti', 'mineral water', 'tomatoes'],
#  ['frozen vegetables', 'spaghetti', 'olive oil', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'shrimp', 'nan'],
#  ['frozen vegetables', 'tomatoes', 'shrimp', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'tomatoes', 'nan'],
#  ['spaghetti', 'ground beef', 'nan', 'grated cheese'],
#  ['tomatoes', 'green tea', 'nan', 'ground beef'],
#  ['milk', 'nan', 'herb & pepper', 'ground beef'],
#  ['nan', 'mineral water', 'herb & pepper', 'ground beef'],
#  ['spaghetti', 'nan', 'herb & pepper', 'ground beef'],
#  ['spaghetti', 'milk', 'mineral water', 'ground beef'],
#  ['milk', 'olive oil', 'nan', 'ground beef'],
#  ['milk', 'soup', 'nan', 'ground beef'],
#  ['spaghetti', 'olive oil', 'mineral water', 'ground beef'],
#  ['spaghetti', 'pancakes', 'mineral water', 'ground beef'],
#  ['spaghetti', 'mineral water', 'tomatoes', 'ground beef'],
#  ['spaghetti', 'nan', 'pepper', 'ground beef'],
#  ['shrimp', 'spaghetti', 'nan', 'ground beef'],
#  ['spaghetti', 'nan', 'tomato sauce', 'ground beef'],
#  ['spaghetti', 'mineral water', 'light cream', 'nan'],
#  ['spaghetti', 'milk', 'olive oil', 'mineral water'],
#  ['spaghetti', 'milk', 'mineral water', 'tomatoes'],
#  ['milk', 'olive oil', 'shrimp', 'nan'],
#  ['soup', 'milk', 'olive oil', 'nan'],
#  ['spaghetti', 'milk', 'olive oil', 'nan'],
#  ['milk', 'soup', 'tomatoes', 'nan'],
#  ['spaghetti', 'milk', 'whole wheat pasta', 'nan'],
#  ['soup', 'olive oil', 'mineral water', 'nan'],
#  ['whole wheat pasta', 'olive oil', 'mineral water', 'nan'],
#  ['spaghetti', 'pancakes', 'olive oil', 'nan'],
#  ['spaghetti', 'olive oil', 'tomatoes', 'nan'],
#  ['spaghetti', 'tomatoes', 'whole wheat rice', 'nan'],
#  ['chocolate', 'ground beef', 'eggs', 'mineral water', 'nan'],
#  ['frozen vegetables', 'chocolate', 'ground beef', 'mineral water', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'chocolate', 'ground beef', 'nan'],
#  ['frozen vegetables', 'chocolate', 'milk', 'mineral water', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'chocolate', 'milk', 'nan'],
#  ['frozen vegetables', 'shrimp', 'chocolate', 'mineral water', 'nan'],
#  ['spaghetti', 'chocolate', 'mineral water', 'olive oil', 'nan'],
#  ['spaghetti', 'shrimp', 'chocolate', 'mineral water', 'nan'],
#  ['frozen vegetables', 'milk', 'eggs', 'mineral water', 'nan'],
#  ['spaghetti', 'milk', 'mineral water', 'frozen smoothie', 'nan'],
#  ['frozen vegetables', 'milk', 'ground beef', 'mineral water', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'milk', 'ground beef', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'ground beef', 'mineral water', 'nan'],
#  ['frozen vegetables', 'milk', 'mineral water', 'olive oil', 'nan'],
#  ['frozen vegetables', 'milk', 'mineral water', 'nan', 'soup'],
#  ['frozen vegetables', 'spaghetti', 'milk', 'mineral water', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'shrimp', 'mineral water', 'nan'],
#  ['frozen vegetables', 'spaghetti', 'tomatoes', 'mineral water', 'nan'],
#  ['spaghetti', 'milk', 'ground beef', 'mineral water', 'nan'],
#  ['spaghetti', 'ground beef', 'mineral water', 'olive oil', 'nan'],
#  ['spaghetti', 'pancakes', 'ground beef', 'mineral water', 'nan'],
#  ['spaghetti', 'tomatoes', 'ground beef', 'mineral water', 'nan'],
#  ['spaghetti', 'milk', 'mineral water', 'olive oil', 'nan'],
#  ['spaghetti', 'tomatoes', 'milk', 'mineral water', 'nan']]
